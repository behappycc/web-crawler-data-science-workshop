# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = pd.read_csv("result.csv")

# %%
data
# Out:
#     category                                              title  \
# 0     Python                                         深入淺出Python
# 1     Python                                         Python機器學習
# 2     Python             EffectivePython中文版寫出良好Python程式的59個具體做法
# 3     Python                              精通Python運用簡單的套件進行現代運算
# 4     Python                                       網站擷取使用Python
# 5     Python                                     初探機器學習使用Python
# 6     Python                       黑帽Python給駭客與滲透測試者的Python開發指南
# 7     Python                                      高效能Python程式設計
# 8     Python                  Python程式設計實務從初學到活用Python開發技巧的16堂課
# 9     Python                                    高效率資料分析使用Python
# 10    Python                                     Python設計模式深入解析
# 11    Python                               流暢的Python清晰簡潔有效的程式設計
# 12    Python                                     測試驅動開發使用Python
# 13    Python                                      用Python開發經典遊戲
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 5 columns):
# category    202 non-null object
# title       202 non-null object
# author      202 non-null object
# tenlong     202 non-null object
# books       202 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 8.0+ KB

# %%
data.tenlong = pd.to_numeric(data.tenlong,errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 5 columns):
# category    202 non-null object
# title       202 non-null object
# author      202 non-null object
# tenlong     200 non-null float64
# books       202 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 8.0+ KB

# %%
data.describe()
# Out:
#           tenlong        books
# count  200.000000   202.000000
# mean   445.095000   467.455446
# std    127.858142   193.724173
# min    151.000000   133.000000
# 25%    379.000000   379.000000
# 50%    415.000000   430.000000
# 75%    517.250000   533.500000
# max    973.000000  2100.000000

# %%
data.groupby("category")

# %%
data.groupby("category").mean()
# Out:
#                tenlong       books
# category
# C           510.600000  523.500000
# C#          510.600000  523.500000
# C++         510.600000  523.500000
# Go          373.125000  363.875000
# Java        440.714286  466.142857
# JavaScript  447.821429  462.607143
# PHP         546.000000  783.900000
# Python      438.911111  439.822222
# R           430.333333  434.756757
# Swift       412.068966  447.103448

# %%
data.groupby("category").sum()
# Out:
#             tenlong  books
# category
# C            5106.0   5235
# C#           5106.0   5235
# C++          5106.0   5235
# Go           5970.0   5822
# Java         3085.0   3263
# JavaScript  12539.0  12953
# PHP          4914.0   7839
# Python      19751.0  19792
# R           15492.0  16086
# Swift       11950.0  12966

# %%
len(data[data['tenlong']<data['books']])
# Out:
# 79

# %%
len(data[data['tenlong']>data['books']])
# Out:
# 42

# %%
data[data['tenlong']>data['books']]
# Out:
#        category                                              title  \
# 23       Python                                     利用Python進行數據分析
# 25       Python                                    Python函式庫語法範例字典
# 27       Python                                      Python計算機視覺編程
# 31       Python                                       Python自然語言處理
# 32       Python                                       用Python寫網絡爬蟲
# 35       Python                                    Python爬蟲開發與項目實戰
# 37       Python                                         Python金融實戰
# 38       Python                                    Python數據挖掘入門與實踐
# 60         Java                                       Java加密與解密的藝術
# 87            R                                           R數據可視化手冊
# 89            R                                            R語言編程藝術
# 91            R                                         機器學習與R語言實戰
# 95            R                                         投資學及其R語言應用
# ...

# %%
data.groupby("category").sum().plot(kind='bar')

# %%
#PHP平均價格最高 Go平均價格最低
#PHP在天龍買 Go可以去博客來買

# %%
data.groupby("category").mean().plot(kind='bar')
